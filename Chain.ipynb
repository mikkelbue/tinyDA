# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

import tinyDA as tda

# %%
b = 1
m = 2
x = np.linspace(0,1)
y_pure = b + m*x

sigma = 0.1
y = y_pure + np.random.normal(scale=sigma, size=x.shape[0])

# %%
plt.plot(x, y_pure)
plt.scatter(x, y)
plt.show()

# %%
mean_prior = np.zeros(2)
cov_prior = np.eye(2)
cov_likelihood = sigma**2*np.eye(x.shape[0])

my_prior = multivariate_normal(mean_prior, cov_prior)
my_loglike = tda.LogLike(y, cov_likelihood)

# %%
class MyLinkFactory(tda.LinkFactory):
    def evaluate_model(self, parameters):
        output = parameters[0] + parameters[1]*x
        qoi = None
        return output, qoi

# %%
my_link_factory = MyLinkFactory(my_prior, my_loglike)

# %%
rwmh_cov = np.eye(2)
rmwh_scaling = 0.1
rwmh_adaptive = True
my_proposal = tda.GaussianRandomWalk(C=rwmh_cov, scaling=rmwh_scaling, adaptive=rwmh_adaptive)

#pcn_scaling = 0.1
#pcn_adaptive = True
#my_proposal = tda.CrankNicolson(C=cov_prior, scaling=pcn_scaling, adaptive=pcn_adaptive)

#am_cov = np.eye(2)
#am_t0 = 2000
#am_sd = 1
#am_epsilon = 1e-6
#my_proposal = tda.AdaptiveMetropolis(C0=am_cov, t0=am_t0, sd=am_sd, epsilon=am_epsilon)

# %%
my_chain = tda.Chain(my_link_factory, my_proposal)

# %%
my_chain.sample(10000)
# Out:
# Running chain, α = 0.667:   0%|          | 0/10000 [00:00<?, ?it/s]/home/mikkel/OneDrive/Projects/tinyDA/git/tinyDA/proposal.py:79: RuntimeWarning: overflow encountered in exp
#   return np.exp(proposal_link.posterior - previous_link.posterior)
# Running chain, α = 0.220: 100%|██████████| 10000/10000 [00:10<00:00, 931.18it/s]

# %%
burnin = 2000

# %%
plt.plot([link.parameters[0] for link in my_chain.chain[burnin:]])

# %%
plt.plot([link.parameters[1] for link in my_chain.chain[burnin:]])
