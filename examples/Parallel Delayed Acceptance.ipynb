# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal

import tinyDA as tda

# %%
np.random.seed(987)

# %%
b = 1
m = 2
x = np.linspace(0,1)
y_pure = b + m*x

sigma = 0.1
y = y_pure + np.random.normal(scale=sigma, size=x.shape[0])

# %%
plt.plot(x, y_pure)
plt.scatter(x, y)
plt.show()

# %%
mean_prior = np.zeros(2)
cov_prior = np.eye(2)
cov_likelihood = sigma**2*np.eye(x.shape[0])

my_prior = multivariate_normal(mean_prior, cov_prior)
my_loglike = tda.LogLike(y, cov_likelihood)

# %%
class MyCoarseLinkFactory(tda.LinkFactory):
    def evaluate_model(self, parameters):
        output = parameters[0] + parameters[1]*x + 0.01
        qoi = None
        return output, qoi

# %%
class MyFineLinkFactory(tda.LinkFactory):
    def evaluate_model(self, parameters):
        output = parameters[0] + parameters[1]*x
        qoi = None
        return output, qoi

# %%
my_link_factory_coarse = MyCoarseLinkFactory(my_prior, my_loglike)
my_link_factory_fine = MyFineLinkFactory(my_prior, my_loglike)

# %%
#rwmh_cov = np.eye(2)
#rmwh_scaling = 0.1
#rwmh_adaptive = True
#my_proposal = tda.GaussianRandomWalk(C=rwmh_cov, scaling=rmwh_scaling, adaptive=rwmh_adaptive)

pcn_scaling = 0.1
pcn_adaptive = True
my_proposal = tda.CrankNicolson(scaling=pcn_scaling, adaptive=pcn_adaptive)

#am_cov = np.eye(2)
#am_t0 = 2000
#am_sd = 1
#am_epsilon = 1e-6
#my_proposal = tda.AdaptiveMetropolis(C0=am_cov, t0=am_t0, sd=am_sd, epsilon=am_epsilon)

# %%
my_chain = tda.ParallelDAChain(my_link_factory_coarse, my_link_factory_fine, my_proposal, subsampling_rate=10)
# Out:
# 2021-08-13 15:54:37,067	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265

# %%
my_chain.sample(2500)
# Out:
# (pid=1051145) /home/mikkel/.local/lib/python3.8/site-packages/tinyDA/proposal.py:320: RuntimeWarning: overflow encountered in exp
# (pid=1051145)   return np.exp(proposal_link.likelihood - previous_link.likelihood)
# (pid=1051146) /home/mikkel/.local/lib/python3.8/site-packages/tinyDA/proposal.py:320: RuntimeWarning: overflow encountered in exp
# (pid=1051146)   return np.exp(proposal_link.likelihood - previous_link.likelihood)

# %%
burnin = 500
parameters = tda.get_parameters(my_chain)
for p in parameters:
    tda.plot_parameters(p, burnin=burnin)

# %%
tda.compute_R_hat(parameters)
# Out:
# array([1.00245703, 1.0011741 ])

# %%
tda.compute_ESS(parameters)
# Out:
# array([62.69492871, 78.9981724 ])
